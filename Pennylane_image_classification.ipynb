# %% [markdown]
# <a href="https://colab.research.google.com/github/kaisarmasum/Quantum-Machine-Learning/blob/main/Pennylane_image_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pennylane
# Out:
# Collecting pennylane
#   Downloading PennyLane-0.32.0-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 12.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy<1.24 in /usr/local/lib/python3.10/dist-packages (from pennylane) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from pennylane) (1.11.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from pennylane) (3.1)
# Collecting rustworkx (from pennylane)
#   Downloading rustworkx-0.13.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 61.8 MB/s eta 0:00:00
# Collecting autograd<=1.5 (from pennylane)
#   Downloading autograd-1.5-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 kB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from pennylane) (0.10.2)
# Requirement already satisfied: appdirs in /usr/local/lib/python3.10/dist-packages (from pennylane) (1.4.4)
# Collecting semantic-version>=2.7 (from pennylane)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Collecting autoray>=0.3.1 (from pennylane)
#   Downloading autoray-0.6.6-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.7/54.7 kB 5.9 MB/s eta 0:00:00
# Requirement already satisfied: cachetools in /usr/local/lib/python3.10/dist-packages (from pennylane) (5.3.1)
# Collecting pennylane-lightning>=0.32 (from pennylane)
#   Downloading PennyLane_Lightning-0.32.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 52.3 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from pennylane) (2.31.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from pennylane) (4.5.0)
# Requirement already satisfied: future>=0.15.2 in /usr/local/lib/python3.10/dist-packages (from autograd<=1.5->pennylane) (0.18.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->pennylane) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->pennylane) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->pennylane) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->pennylane) (2023.7.22)
# Installing collected packages: semantic-version, rustworkx, autoray, autograd, pennylane-lightning, pennylane
#   Attempting uninstall: autograd
#     Found existing installation: autograd 1.6.2
#     Uninstalling autograd-1.6.2:
#       Successfully uninstalled autograd-1.6.2
# Successfully installed autograd-1.5 autoray-0.6.6 pennylane-0.32.0 pennylane-lightning-0.32.0 rustworkx-0.13.2 semantic-version-2.10.0

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pennylane as qml
from pennylane import numpy as np
from pennylane.templates import RandomLayers
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt

# %%
n_epochs = 30   # Number of optimization epochs
n_layers = 6   # Number of random layers
n_train = 50    # Size of the train dataset
n_test = 30     # Size of the test dataset

SAVE_PATH = "/content/gdrive/MyDrive/Colab Notebooks/quanvolution/" # Data saving folder
PREPROCESS = True           # If False, skip quantum processing and load data from SAVE_PATH
np.random.seed(0)           # Seed for NumPy random number generator
tf.random.set_seed(0)       # Seed for TensorFlow random number generator

# %%
mnist_dataset = keras.datasets.mnist
(train_images, train_labels), (test_images, test_labels) = mnist_dataset.load_data()

# Reduce dataset size
train_images = train_images[:n_train]
train_labels = train_labels[:n_train]
test_images = test_images[:n_test]
test_labels = test_labels[:n_test]

# Normalize pixel values within 0 and 1
train_images = train_images / 255
test_images = test_images / 255

# Add extra dimension for convolution channels
train_images = np.array(train_images[..., tf.newaxis], requires_grad=False)
test_images = np.array(test_images[..., tf.newaxis], requires_grad=False)

# %%
dev = qml.device("default.qubit", wires=4)
# Random circuit parameters
rand_params = np.random.uniform(high=2 * np.pi, size=(n_layers, 4))

@qml.qnode(dev, interface="autograd")
def circuit(phi):
    # Encoding of 4 classical input values
    for j in range(4):
        qml.RY(np.pi * phi[j], wires=j)

    # Random quantum circuit
    RandomLayers(rand_params, wires=list(range(4)))

    # Measurement producing 4 classical output values
    return [qml.expval(qml.PauliZ(j)) for j in range(4)]

# %%
def quanv(image):
    """Convolves the input image with many applications of the same quantum circuit."""
    out = np.zeros((14, 14, 4))

    # Loop over the coordinates of the top-left pixel of 2X2 squares
    for j in range(0, 28, 2):
        for k in range(0, 28, 2):
            # Process a squared 2x2 region of the image with a quantum circuit
            q_results = circuit(
                [
                    image[j, k, 0],
                    image[j, k + 1, 0],
                    image[j + 1, k, 0],
                    image[j + 1, k + 1, 0]
                ]
            )
            # Assign expectation values to different channels of the output pixel (j/2, k/2)
            for c in range(4):
                out[j // 2, k // 2, c] = q_results[c]
    return out

# %%
if PREPROCESS == True:
    q_train_images = []
    print("Quantum pre-processing of train images:")
    for idx, img in enumerate(train_images):
        print("{}/{}        ".format(idx + 1, n_train), end="\r")
        q_train_images.append(quanv(img))
    q_train_images = np.asarray(q_train_images)

    q_test_images = []
    print("\nQuantum pre-processing of test images:")
    for idx, img in enumerate(test_images):
        print("{}/{}        ".format(idx + 1, n_test), end="\r")
        q_test_images.append(quanv(img))
    q_test_images = np.asarray(q_test_images)

    # Save pre-processed images
    np.save(SAVE_PATH + "q_train_images.npy", q_train_images)
    np.save(SAVE_PATH + "q_test_images.npy", q_test_images)


# Load pre-processed images
q_train_images = np.load(SAVE_PATH + "q_train_images.npy")
q_test_images = np.load(SAVE_PATH + "q_test_images.npy")
# Out:
# Quantum pre-processing of train images:
#
# Quantum pre-processing of test images:

# %%
n_samples = 4
n_channels = 4
fig, axes = plt.subplots(1 + n_channels, n_samples, figsize=(10, 10))
for k in range(n_samples):
    axes[0, 0].set_ylabel("Input")
    if k != 0:
        axes[0, k].yaxis.set_visible(False)
    axes[0, k].imshow(train_images[k, :, :, 0], cmap="gray")

    # Plot all output channels
    for c in range(n_channels):
        axes[c + 1, 0].set_ylabel("Output [ch. {}]".format(c))
        if k != 0:
            axes[c, k].yaxis.set_visible(False)
        axes[c + 1, k].imshow(q_train_images[k, :, :, c], cmap="gray")

plt.tight_layout()
plt.show()

# %%
def MyModel():
    """Initializes and returns a custom Keras model
    which is ready to be trained."""
    model = keras.models.Sequential([
        keras.layers.Flatten(),
        keras.layers.Dense(10, activation="softmax")
    ])

    model.compile(
        optimizer='adam',
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"],
    )
    return model

# %%
q_model = MyModel()

q_history = q_model.fit(
    q_train_images,
    train_labels,
    validation_data=(q_test_images, test_labels),
    batch_size=2,
    epochs=n_epochs,
    verbose=2,
)
# Out:
# Epoch 1/30
# 25/25 - 1s - loss: 2.4016 - accuracy: 0.1200 - val_loss: 2.3408 - val_accuracy: 0.1667 - 630ms/epoch - 25ms/step
# Epoch 2/30
# 25/25 - 0s - loss: 2.1236 - accuracy: 0.2400 - val_loss: 2.2239 - val_accuracy: 0.2333 - 81ms/epoch - 3ms/step
# Epoch 3/30
# 25/25 - 0s - loss: 1.9563 - accuracy: 0.3200 - val_loss: 2.2017 - val_accuracy: 0.3000 - 119ms/epoch - 5ms/step
# Epoch 4/30
# 25/25 - 0s - loss: 1.7742 - accuracy: 0.5200 - val_loss: 2.1293 - val_accuracy: 0.3000 - 81ms/epoch - 3ms/step
# Epoch 5/30
# 25/25 - 0s - loss: 1.6367 - accuracy: 0.7400 - val_loss: 2.0408 - val_accuracy: 0.3667 - 84ms/epoch - 3ms/step
# Epoch 6/30
# 25/25 - 0s - loss: 1.5111 - accuracy: 0.7800 - val_loss: 2.0232 - val_accuracy: 0.3333 - 83ms/epoch - 3ms/step
# Epoch 7/30
# 25/25 - 0s - loss: 1.3637 - accuracy: 0.9200 - val_loss: 1.9630 - val_accuracy: 0.3333 - 88ms/epoch - 4ms/step
# Epoch 8/30
# 25/25 - 0s - loss: 1.2558 - accuracy: 0.9000 - val_loss: 1.9191 - val_accuracy: 0.3333 - 124ms/epoch - 5ms/step
# Epoch 9/30
# 25/25 - 0s - loss: 1.1328 - accuracy: 0.9400 - val_loss: 1.8175 - val_accuracy: 0.4333 - 90ms/epoch - 4ms/step
# Epoch 10/30
# 25/25 - 0s - loss: 1.0221 - accuracy: 0.9600 - val_loss: 1.8113 - val_accuracy: 0.4333 - 86ms/epoch - 3ms/step
# Epoch 11/30
# 25/25 - 0s - loss: 0.9604 - accuracy: 0.9400 - val_loss: 1.7749 - val_accuracy: 0.4000 - 122ms/epoch - 5ms/step
# Epoch 12/30
# 25/25 - 0s - loss: 0.8789 - accuracy: 1.0000 - val_loss: 1.7636 - val_accuracy: 0.4667 - 83ms/epoch - 3ms/step
# Epoch 13/30
# 25/25 - 0s - loss: 0.7997 - accuracy: 1.0000 - val_loss: 1.6971 - val_accuracy: 0.5333 - 130ms/epoch - 5ms/step
# Epoch 14/30
# 25/25 - 0s - loss: 0.7465 - accuracy: 0.9800 - val_loss: 1.6846 - val_accuracy: 0.4667 - 129ms/epoch - 5ms/step
# Epoch 15/30
# 25/25 - 0s - loss: 0.6778 - accuracy: 1.0000 - val_loss: 1.6335 - val_accuracy: 0.5000 - 129ms/epoch - 5ms/step
# Epoch 16/30
# 25/25 - 0s - loss: 0.6196 - accuracy: 1.0000 - val_loss: 1.6303 - val_accuracy: 0.5667 - 91ms/epoch - 4ms/step
# Epoch 17/30
# 25/25 - 0s - loss: 0.5874 - accuracy: 1.0000 - val_loss: 1.6002 - val_accuracy: 0.5000 - 134ms/epoch - 5ms/step
# Epoch 18/30
# 25/25 - 0s - loss: 0.5378 - accuracy: 1.0000 - val_loss: 1.6021 - val_accuracy: 0.4667 - 82ms/epoch - 3ms/step
# Epoch 19/30
# 25/25 - 0s - loss: 0.4994 - accuracy: 1.0000 - val_loss: 1.5630 - val_accuracy: 0.6000 - 138ms/epoch - 6ms/step
# Epoch 20/30
# 25/25 - 0s - loss: 0.4663 - accuracy: 1.0000 - val_loss: 1.5189 - val_accuracy: 0.5333 - 135ms/epoch - 5ms/step
# Epoch 21/30
# 25/25 - 0s - loss: 0.4336 - accuracy: 1.0000 - val_loss: 1.5697 - val_accuracy: 0.5333 - 82ms/epoch - 3ms/step
# Epoch 22/30
# 25/25 - 0s - loss: 0.4014 - accuracy: 1.0000 - val_loss: 1.5004 - val_accuracy: 0.6000 - 142ms/epoch - 6ms/step
# Epoch 23/30
# 25/25 - 0s - loss: 0.3760 - accuracy: 1.0000 - val_loss: 1.4928 - val_accuracy: 0.6000 - 95ms/epoch - 4ms/step
# Epoch 24/30
# 25/25 - 0s - loss: 0.3521 - accuracy: 1.0000 - val_loss: 1.4712 - val_accuracy: 0.6000 - 128ms/epoch - 5ms/step
# Epoch 25/30
# 25/25 - 0s - loss: 0.3351 - accuracy: 1.0000 - val_loss: 1.4696 - val_accuracy: 0.6000 - 135ms/epoch - 5ms/step
# Epoch 26/30
# 25/25 - 0s - loss: 0.3104 - accuracy: 1.0000 - val_loss: 1.4587 - val_accuracy: 0.6000 - 88ms/epoch - 4ms/step
# Epoch 27/30
# 25/25 - 0s - loss: 0.2920 - accuracy: 1.0000 - val_loss: 1.4334 - val_accuracy: 0.6000 - 130ms/epoch - 5ms/step
# Epoch 28/30
# 25/25 - 0s - loss: 0.2830 - accuracy: 1.0000 - val_loss: 1.4311 - val_accuracy: 0.6000 - 90ms/epoch - 4ms/step
# Epoch 29/30
# 25/25 - 0s - loss: 0.2629 - accuracy: 1.0000 - val_loss: 1.4277 - val_accuracy: 0.6000 - 88ms/epoch - 4ms/step
# Epoch 30/30
# 25/25 - 0s - loss: 0.2478 - accuracy: 1.0000 - val_loss: 1.4024 - val_accuracy: 0.6000 - 124ms/epoch - 5ms/step

# %%
c_model = MyModel()

c_history = c_model.fit(
    train_images,
    train_labels,
    validation_data=(test_images, test_labels),
    batch_size=4,
    epochs=n_epochs,
    verbose=2,
)
# Out:
# Epoch 1/30
# 13/13 - 1s - loss: 2.3246 - accuracy: 0.1600 - val_loss: 2.2564 - val_accuracy: 0.1667 - 631ms/epoch - 49ms/step
# Epoch 2/30
# 13/13 - 0s - loss: 1.9404 - accuracy: 0.3400 - val_loss: 2.0784 - val_accuracy: 0.3000 - 76ms/epoch - 6ms/step
# Epoch 3/30
# 13/13 - 0s - loss: 1.6533 - accuracy: 0.5400 - val_loss: 1.9318 - val_accuracy: 0.3667 - 76ms/epoch - 6ms/step
# Epoch 4/30
# 13/13 - 0s - loss: 1.4246 - accuracy: 0.7400 - val_loss: 1.8005 - val_accuracy: 0.4333 - 63ms/epoch - 5ms/step
# Epoch 5/30
# 13/13 - 0s - loss: 1.2307 - accuracy: 0.8000 - val_loss: 1.6836 - val_accuracy: 0.4667 - 67ms/epoch - 5ms/step
# Epoch 6/30
# 13/13 - 0s - loss: 1.0770 - accuracy: 0.9000 - val_loss: 1.5964 - val_accuracy: 0.4667 - 78ms/epoch - 6ms/step
# Epoch 7/30
# 13/13 - 0s - loss: 0.9427 - accuracy: 0.9000 - val_loss: 1.5336 - val_accuracy: 0.4667 - 59ms/epoch - 5ms/step
# Epoch 8/30
# 13/13 - 0s - loss: 0.8313 - accuracy: 0.9200 - val_loss: 1.4675 - val_accuracy: 0.4667 - 70ms/epoch - 5ms/step
# Epoch 9/30
# 13/13 - 0s - loss: 0.7396 - accuracy: 0.9200 - val_loss: 1.4131 - val_accuracy: 0.5667 - 67ms/epoch - 5ms/step
# Epoch 10/30
# 13/13 - 0s - loss: 0.6588 - accuracy: 0.9200 - val_loss: 1.3733 - val_accuracy: 0.5667 - 70ms/epoch - 5ms/step
# Epoch 11/30
# 13/13 - 0s - loss: 0.5964 - accuracy: 0.9200 - val_loss: 1.3312 - val_accuracy: 0.6000 - 72ms/epoch - 6ms/step
# Epoch 12/30
# 13/13 - 0s - loss: 0.5398 - accuracy: 0.9400 - val_loss: 1.3228 - val_accuracy: 0.6333 - 68ms/epoch - 5ms/step
# Epoch 13/30
# 13/13 - 0s - loss: 0.4884 - accuracy: 0.9400 - val_loss: 1.2927 - val_accuracy: 0.6333 - 67ms/epoch - 5ms/step
# Epoch 14/30
# 13/13 - 0s - loss: 0.4421 - accuracy: 0.9800 - val_loss: 1.2509 - val_accuracy: 0.6667 - 69ms/epoch - 5ms/step
# Epoch 15/30
# 13/13 - 0s - loss: 0.4013 - accuracy: 1.0000 - val_loss: 1.2266 - val_accuracy: 0.6333 - 69ms/epoch - 5ms/step
# Epoch 16/30
# 13/13 - 0s - loss: 0.3676 - accuracy: 1.0000 - val_loss: 1.2091 - val_accuracy: 0.6333 - 67ms/epoch - 5ms/step
# Epoch 17/30
# 13/13 - 0s - loss: 0.3394 - accuracy: 1.0000 - val_loss: 1.1952 - val_accuracy: 0.6333 - 69ms/epoch - 5ms/step
# Epoch 18/30
# 13/13 - 0s - loss: 0.3124 - accuracy: 1.0000 - val_loss: 1.1726 - val_accuracy: 0.6667 - 70ms/epoch - 5ms/step
# Epoch 19/30
# 13/13 - 0s - loss: 0.2869 - accuracy: 1.0000 - val_loss: 1.1674 - val_accuracy: 0.6667 - 68ms/epoch - 5ms/step
# Epoch 20/30
# 13/13 - 0s - loss: 0.2669 - accuracy: 1.0000 - val_loss: 1.1471 - val_accuracy: 0.6667 - 67ms/epoch - 5ms/step
# Epoch 21/30
# 13/13 - 0s - loss: 0.2479 - accuracy: 1.0000 - val_loss: 1.1452 - val_accuracy: 0.6667 - 70ms/epoch - 5ms/step
# Epoch 22/30
# 13/13 - 0s - loss: 0.2305 - accuracy: 1.0000 - val_loss: 1.1323 - val_accuracy: 0.6667 - 57ms/epoch - 4ms/step
# Epoch 23/30
# 13/13 - 0s - loss: 0.2147 - accuracy: 1.0000 - val_loss: 1.1206 - val_accuracy: 0.6667 - 70ms/epoch - 5ms/step
# Epoch 24/30
# 13/13 - 0s - loss: 0.2009 - accuracy: 1.0000 - val_loss: 1.1123 - val_accuracy: 0.6667 - 72ms/epoch - 6ms/step
# Epoch 25/30
# 13/13 - 0s - loss: 0.1901 - accuracy: 1.0000 - val_loss: 1.1065 - val_accuracy: 0.6667 - 61ms/epoch - 5ms/step
# Epoch 26/30
# 13/13 - 0s - loss: 0.1771 - accuracy: 1.0000 - val_loss: 1.1013 - val_accuracy: 0.6667 - 62ms/epoch - 5ms/step
# Epoch 27/30
# 13/13 - 0s - loss: 0.1674 - accuracy: 1.0000 - val_loss: 1.0903 - val_accuracy: 0.7000 - 65ms/epoch - 5ms/step
# Epoch 28/30
# 13/13 - 0s - loss: 0.1589 - accuracy: 1.0000 - val_loss: 1.0845 - val_accuracy: 0.6667 - 63ms/epoch - 5ms/step
# Epoch 29/30
# 13/13 - 0s - loss: 0.1492 - accuracy: 1.0000 - val_loss: 1.0825 - val_accuracy: 0.6667 - 67ms/epoch - 5ms/step
# Epoch 30/30
# 13/13 - 0s - loss: 0.1405 - accuracy: 1.0000 - val_loss: 1.0774 - val_accuracy: 0.6667 - 58ms/epoch - 4ms/step

# %%
import matplotlib.pyplot as plt

plt.style.use("seaborn")
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(6, 9))

ax1.plot(q_history.history["val_accuracy"], "-ob", label="With quantum layer")
ax1.plot(c_history.history["val_accuracy"], "-og", label="Without quantum layer")
ax1.set_ylabel("Accuracy")
ax1.set_ylim([0, 1])
ax1.set_xlabel("Epoch")
ax1.legend()

ax2.plot(q_history.history["val_loss"], "-ob", label="With quantum layer")
ax2.plot(c_history.history["val_loss"], "-og", label="Without quantum layer")
ax2.set_ylabel("Loss")
ax2.set_ylim(top=2.5)
ax2.set_xlabel("Epoch")
ax2.legend()
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-48-c3ef9ba498fb>:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")
